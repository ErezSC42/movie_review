# %%
import torch
import pandas as pd
import numpy as np
from TextCNN_regression import TextCNN
import gzip
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from Embedder import Embedder

# %%
FILENAME = "movies.txt"
COLUMNS = ["productId",
           "userId",
           "profileName",
           "helpfulness",
           "score",
           "time",
           "summary",
           "text"]
COL_NUM = 8
REVIEW_NUM = 140000
PADDED_LEN = 200
GLOVE_BINARY_PATH = "glove.6B.50d.txt"

# %%
df = pd.read_csv(FILENAME,
                 header=None,
                 delimiter="\n",
                 error_bad_lines=False,
                 skip_blank_lines=True,
                 encoding="latin-1",
                 nrows=COL_NUM*REVIEW_NUM)
df = pd.DataFrame(np.reshape(df.values,(REVIEW_NUM,COL_NUM)),columns=COLUMNS)

# %%
df["productId"] = df["productId"].str.replace("product/productId:","")
for col in COLUMNS[1:]:
    df[col] = df[col].str.replace("review/" + col + ":","")

# %%
df.head()
# Out:
#      productId           userId                                  profileName  \
# 0   B003AI2VGA   A141HP4LYPWMSR             Brian E. Erland "Rainbow Sphinx"
# 1   B003AI2VGA   A328S9RN3U5M68                                   Grady Harp
# 2   B003AI2VGA   A1I7QGUDP043DG                    Chrissy K. McVay "Writer"
# 3   B003AI2VGA   A1M5405JH9THP9                                 golgotha.gov
# 4   B003AI2VGA    ATXL536YX71TR   KerrLines "&#34;Movies,Music,Theatre&#34;"
#
#   helpfulness score         time  \
# 0         7/7   3.0   1182729600
# 1         4/4   3.0   1181952000
# 2        8/10   5.0   1164844800
# 3         1/1   3.0   1197158400
# 4         1/1   3.0   1188345600
#
#                                              summary  \
# 0   "There Is So Much Darkness Now ~ Come For The...
# 1   Worthwhile and Important Story Hampered by Po...
# 2                      This movie needed to be made.
# 3                  distantly based on a real tragedy
# 4   "What's going on down in Juarez and shining a...
#
#                                                 text
# 0   Synopsis: On the daily trek from Juarez, Mexi...
# 1   THE VIRGIN OF JUAREZ is based on true events ...
# 2   The scenes in this film can be very disquieti...
# 3   THE VIRGIN OF JUAREZ (2006)<br />directed by ...
# 4   Informationally, this SHOWTIME original is es...

# %%
X = df["text"]
y = df["score"].astype("float").astype("int").values.reshape([-1,1])
y_one_hot = OneHotEncoder().fit_transform(y).toarray()
# Out:
# /home/deep3/text/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
#df[df["score"] == "review/helpfulness: 0/0"]

# %%
embedder = Embedder(None,50,PADDED_LEN,GLOVE_BINARY_PATH)
X_embedded = embedder.str_series_to_image(X)
# Out:
# 140000

# %%
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import TensorDataset,DataLoader

# %%
LEARNING_RATE = 0.025
FC_LAYER = 100
CLASSES_LEN = 1
EMBEDDING_DIM = 50
CONV_FILTERS = 256
EPOCHS = 100
TRAIN_TEST_RATION = 0.2
TRAIN_SIZE = (1 - TRAIN_TEST_RATION) * len(X_embedded)
TEST_SIZE = (TRAIN_TEST_RATION) * len(X_embedded)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
X_train, X_test, y_train, y_test = train_test_split(X_embedded, y, test_size=TRAIN_TEST_RATION)
X_train = X_train.reshape([-1,1,PADDED_LEN,EMBEDDING_DIM])
X_test = X_test.reshape([-1,1,PADDED_LEN,EMBEDDING_DIM])
X_train_tensor = torch.Tensor(X_train).to(device)
X_test_tensor = torch.Tensor(X_test).to(device)
y_train_tensor = torch.Tensor(y_train).to(device)
y_test_tensor = torch.Tensor(y_test).to(device)
#y_train_tensor = torch.Tensor(y_train).to(device)
#y_test_tensor = torch.Tensor(y_test).to(device)

train_dataset = TensorDataset(X_train_tensor,y_train_tensor)
test_dataset = TensorDataset(X_test_tensor,y_test_tensor)
trainloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
testloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
model = TextCNN(hidden_units=FC_LAYER,
                output_len=CLASSES_LEN,
                textcnn_filter_count=CONV_FILTERS,
                sentence_max_size=PADDED_LEN,
                word_embedding_dimension=EMBEDDING_DIM)
#criterion = nn.CrossEntropyLoss()

criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters())
model.to(device)
# Out:
# TextCNN(
#   (conv3): Conv2d(1, 256, kernel_size=(3, 50), stride=(1, 1))
#   (conv4): Conv2d(1, 256, kernel_size=(4, 50), stride=(1, 1))
#   (conv5): Conv2d(1, 256, kernel_size=(5, 50), stride=(1, 1))
#   (Max3_pool): MaxPool2d(kernel_size=(198, 1), stride=(198, 1), padding=0, dilation=1, ceil_mode=False)
#   (Max4_pool): MaxPool2d(kernel_size=(197, 1), stride=(197, 1), padding=0, dilation=1, ceil_mode=False)
#   (Max5_pool): MaxPool2d(kernel_size=(196, 1), stride=(196, 1), padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=768, out_features=100, bias=True)
#   (dropout1): Dropout(p=0.3)
#   (linear1): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
X_train.shape
# Out:
# (112000, 1, 200, 50)

# %%
def check_accuracy_classification(data_loader,model,name):
    correct = 0
    total = 0
    total = len(data_loader)
    testloader.dataset.tensors[0]
    with torch.no_grad():
        for data in data_loader:
            images, labels = data
            outputs = model(images)
            labels = torch.max(labels, 1)[1]
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print('Accuracy of the network on the '+name +' reviews: %d %%' % (100 * correct / total))

# %%
def check_accuracy_mse(data_loader,model,name):
    correct = 0
    total = 0
    batch_losses = []
    diffs = []
    with torch.no_grad():
        for data in data_loader:
            images, labels = data
            outputs = model(images)
            class_outputs = torch.round(outputs)
            #print(class_outputs)
            #print(labels)
            loss = criterion(outputs, labels)
            batch_losses.append(loss.item())
            diff = torch.mean(torch.abs(labels - class_outputs)).item()
            diffs.append(diff)
            total += labels.size(0)
            correct += (class_outputs == labels).sum().item()
    #print(batch_losses)
    mse = np.array(batch_losses).mean()
    print('MSE of the network on the '+name +' reviews: %f' % mse)
    print('Accuracy of the network on the '+name +' reviews: %d %%' % (100 * correct / total))
    print('average diff of the network on the '+name +' reviews: %f' % np.mean(np.array(diffs)))

# %%
for epoch in range(EPOCHS):  # loop over the dataset multiple times
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        # forward + backward + optimize
        outputs = model(inputs)
        #loss = criterion(outputs,labels)
        loss = criterion(outputs,labels)
        loss.backward()
        optimizer.step()
        # zero the parameter gradients
        optimizer.zero_grad()
        # print statistics
        running_loss += loss.item()
        #if i % 100 == 0:    # print every 2000 mini-batches
    print('[%d, %5d] loss: %.3f' % (epoch + 1, i + 1, running_loss / 2))
    #print('epoch: [%d] loss: %.3f' % (epoch + 1, running_loss))
    check_accuracy_mse(trainloader,model,"train")
    check_accuracy_mse(testloader,model,"test")
print('Finished Training')
# Out:
# [1,  3500] loss: 1004.196
# MSE of the network on the train reviews: 0.542732
# Accuracy of the network on the train reviews: 51 %
# average diff of the network on the train reviews: 0.556223
# MSE of the network on the test reviews: 1.173278
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.832536
# [2,  3500] loss: 996.459
# MSE of the network on the train reviews: 0.562126
# Accuracy of the network on the train reviews: 49 %
# average diff of the network on the train reviews: 0.573518
# MSE of the network on the test reviews: 1.229797
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.850929
# [3,  3500] loss: 996.672
# MSE of the network on the train reviews: 0.551005
# Accuracy of the network on the train reviews: 52 %
# average diff of the network on the train reviews: 0.547107
# MSE of the network on the test reviews: 1.242208
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.842679
# [4,  3500] loss: 1001.385
# MSE of the network on the train reviews: 0.533121
# Accuracy of the network on the train reviews: 52 %
# average diff of the network on the train reviews: 0.544098
# MSE of the network on the test reviews: 1.179776
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.830393
# [5,  3500] loss: 985.067
# MSE of the network on the train reviews: 0.524721
# Accuracy of the network on the train reviews: 53 %
# average diff of the network on the train reviews: 0.539625
# MSE of the network on the test reviews: 1.214816
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.842679
# [6,  3500] loss: 986.570
# MSE of the network on the train reviews: 0.525577
# Accuracy of the network on the train reviews: 52 %
# average diff of the network on the train reviews: 0.542071
# MSE of the network on the test reviews: 1.174350
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.835179
# [7,  3500] loss: 980.773
# MSE of the network on the train reviews: 0.572014
# Accuracy of the network on the train reviews: 51 %
# average diff of the network on the train reviews: 0.562929
# MSE of the network on the test reviews: 1.245858
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.839607
# [8,  3500] loss: 972.122
# MSE of the network on the train reviews: 0.521998
# Accuracy of the network on the train reviews: 52 %
# average diff of the network on the train reviews: 0.543000
# MSE of the network on the test reviews: 1.196707
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.840429
# [9,  3500] loss: 972.604
# MSE of the network on the train reviews: 0.544490
# Accuracy of the network on the train reviews: 50 %
# average diff of the network on the train reviews: 0.564937
# MSE of the network on the test reviews: 1.189909
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.849071
# [10,  3500] loss: 969.923
# MSE of the network on the train reviews: 0.537584
# Accuracy of the network on the train reviews: 51 %
# average diff of the network on the train reviews: 0.552036
# MSE of the network on the test reviews: 1.170807
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.831679
# [11,  3500] loss: 972.119
# MSE of the network on the train reviews: 0.522400
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.530411
# MSE of the network on the test reviews: 1.205470
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.831571
# [12,  3500] loss: 961.098
# MSE of the network on the train reviews: 0.609557
# Accuracy of the network on the train reviews: 45 %
# average diff of the network on the train reviews: 0.621080
# MSE of the network on the test reviews: 1.223459
# Accuracy of the network on the test reviews: 32 %
# average diff of the network on the test reviews: 0.882429
# [13,  3500] loss: 956.436
# MSE of the network on the train reviews: 0.543510
# Accuracy of the network on the train reviews: 52 %
# average diff of the network on the train reviews: 0.543982
# MSE of the network on the test reviews: 1.239917
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.839107
# [14,  3500] loss: 960.480
# MSE of the network on the train reviews: 0.546959
# Accuracy of the network on the train reviews: 53 %
# average diff of the network on the train reviews: 0.543116
# MSE of the network on the test reviews: 1.280127
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.851000
# [15,  3500] loss: 956.667
# MSE of the network on the train reviews: 0.536383
# Accuracy of the network on the train reviews: 53 %
# average diff of the network on the train reviews: 0.538080
# MSE of the network on the test reviews: 1.259861
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.843929
# [16,  3500] loss: 943.449
# MSE of the network on the train reviews: 0.507836
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.526991
# MSE of the network on the test reviews: 1.185959
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.831571
# [17,  3500] loss: 949.473
# MSE of the network on the train reviews: 0.506689
# Accuracy of the network on the train reviews: 53 %
# average diff of the network on the train reviews: 0.534509
# MSE of the network on the test reviews: 1.195043
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.838571
# [18,  3500] loss: 942.511
# MSE of the network on the train reviews: 0.562248
# Accuracy of the network on the train reviews: 52 %
# average diff of the network on the train reviews: 0.554634
# MSE of the network on the test reviews: 1.300400
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.858071
# [19,  3500] loss: 942.698
# MSE of the network on the train reviews: 0.518718
# Accuracy of the network on the train reviews: 53 %
# average diff of the network on the train reviews: 0.534616
# MSE of the network on the test reviews: 1.232645
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.849429
# [20,  3500] loss: 938.586
# MSE of the network on the train reviews: 0.501444
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.527705
# MSE of the network on the test reviews: 1.186722
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.835643
# [21,  3500] loss: 939.780
# MSE of the network on the train reviews: 0.517373
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.527045
# MSE of the network on the test reviews: 1.263625
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.848107
# [22,  3500] loss: 936.602
# MSE of the network on the train reviews: 0.526970
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.529277
# MSE of the network on the test reviews: 1.292040
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.852107
# [23,  3500] loss: 928.250
# MSE of the network on the train reviews: 0.545241
# Accuracy of the network on the train reviews: 50 %
# average diff of the network on the train reviews: 0.567420
# MSE of the network on the test reviews: 1.244913
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.863679
# [24,  3500] loss: 932.779
# MSE of the network on the train reviews: 0.544423
# Accuracy of the network on the train reviews: 53 %
# average diff of the network on the train reviews: 0.544018
# MSE of the network on the test reviews: 1.289042
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.846964
# [25,  3500] loss: 921.910
# MSE of the network on the train reviews: 0.541217
# Accuracy of the network on the train reviews: 53 %
# average diff of the network on the train reviews: 0.541759
# MSE of the network on the test reviews: 1.302548
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.860000
# [26,  3500] loss: 928.873
# MSE of the network on the train reviews: 0.529700
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.528937
# MSE of the network on the test reviews: 1.300989
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.858571
# [27,  3500] loss: 914.790
# MSE of the network on the train reviews: 0.552480
# Accuracy of the network on the train reviews: 48 %
# average diff of the network on the train reviews: 0.584045
# MSE of the network on the test reviews: 1.221390
# Accuracy of the network on the test reviews: 33 %
# average diff of the network on the test reviews: 0.871000
# [28,  3500] loss: 913.427
# MSE of the network on the train reviews: 0.491090
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.520152
# MSE of the network on the test reviews: 1.227293
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.846071
# [29,  3500] loss: 907.360
# MSE of the network on the train reviews: 0.539117
# Accuracy of the network on the train reviews: 53 %
# average diff of the network on the train reviews: 0.542107
# MSE of the network on the test reviews: 1.292529
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.860000
# [30,  3500] loss: 913.862
# MSE of the network on the train reviews: 0.521088
# Accuracy of the network on the train reviews: 51 %
# average diff of the network on the train reviews: 0.553080
# MSE of the network on the test reviews: 1.201617
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.851143
# [31,  3500] loss: 912.926
# MSE of the network on the train reviews: 0.498440
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.521179
# MSE of the network on the test reviews: 1.277321
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.856536
# [32,  3500] loss: 908.233
# MSE of the network on the train reviews: 0.484598
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.510911
# MSE of the network on the test reviews: 1.234682
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.846393
# [33,  3500] loss: 913.066
# MSE of the network on the train reviews: 0.501523
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.523366
# MSE of the network on the test reviews: 1.260075
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.855107
# [34,  3500] loss: 908.803
# MSE of the network on the train reviews: 0.496917
# Accuracy of the network on the train reviews: 53 %
# average diff of the network on the train reviews: 0.529179
# MSE of the network on the test reviews: 1.233059
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.853571
# [35,  3500] loss: 904.769
# MSE of the network on the train reviews: 0.487828
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.511687
# MSE of the network on the test reviews: 1.234574
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.839643
# [36,  3500] loss: 904.908
# MSE of the network on the train reviews: 0.484080
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.511625
# MSE of the network on the test reviews: 1.246425
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.846821
# [37,  3500] loss: 899.087
# MSE of the network on the train reviews: 0.527875
# Accuracy of the network on the train reviews: 50 %
# average diff of the network on the train reviews: 0.563643
# MSE of the network on the test reviews: 1.270434
# Accuracy of the network on the test reviews: 33 %
# average diff of the network on the test reviews: 0.882036
# [38,  3500] loss: 903.319
# MSE of the network on the train reviews: 0.545697
# Accuracy of the network on the train reviews: 49 %
# average diff of the network on the train reviews: 0.579446
# MSE of the network on the test reviews: 1.247705
# Accuracy of the network on the test reviews: 33 %
# average diff of the network on the test reviews: 0.884000
# [39,  3500] loss: 900.941
# MSE of the network on the train reviews: 0.496805
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.519116
# MSE of the network on the test reviews: 1.273286
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.851321
# [40,  3500] loss: 889.413
# MSE of the network on the train reviews: 0.505499
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.523054
# MSE of the network on the test reviews: 1.291457
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.858750
# [41,  3500] loss: 891.353
# MSE of the network on the train reviews: 0.493890
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.527134
# MSE of the network on the test reviews: 1.233283
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.858250
# [42,  3500] loss: 899.900
# MSE of the network on the train reviews: 0.489897
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.510911
# MSE of the network on the test reviews: 1.245880
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.844250
# [43,  3500] loss: 889.745
# MSE of the network on the train reviews: 0.501872
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.522705
# MSE of the network on the test reviews: 1.263949
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.850750
# [44,  3500] loss: 896.110
# MSE of the network on the train reviews: 0.488761
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.522071
# MSE of the network on the test reviews: 1.258641
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.856821
# [45,  3500] loss: 885.188
# MSE of the network on the train reviews: 0.483215
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.510134
# MSE of the network on the test reviews: 1.229570
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.839714
# [46,  3500] loss: 891.817
# MSE of the network on the train reviews: 0.511013
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.528830
# MSE of the network on the test reviews: 1.286296
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.858536
# [47,  3500] loss: 892.023
# MSE of the network on the train reviews: 0.553184
# Accuracy of the network on the train reviews: 49 %
# average diff of the network on the train reviews: 0.583205
# MSE of the network on the test reviews: 1.263120
# Accuracy of the network on the test reviews: 33 %
# average diff of the network on the test reviews: 0.885536
# [48,  3500] loss: 881.879
# MSE of the network on the train reviews: 0.484339
# Accuracy of the network on the train reviews: 56 %
# average diff of the network on the train reviews: 0.508929
# MSE of the network on the test reviews: 1.273693
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.854821
# [49,  3500] loss: 881.321
# MSE of the network on the train reviews: 0.477585
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.510259
# MSE of the network on the test reviews: 1.255691
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.856464
# [50,  3500] loss: 884.506
# MSE of the network on the train reviews: 0.544981
# Accuracy of the network on the train reviews: 49 %
# average diff of the network on the train reviews: 0.580152
# MSE of the network on the test reviews: 1.243265
# Accuracy of the network on the test reviews: 33 %
# average diff of the network on the test reviews: 0.878036
# [51,  3500] loss: 883.645
# MSE of the network on the train reviews: 0.504010
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.518277
# MSE of the network on the test reviews: 1.292589
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.857786
# [52,  3500] loss: 882.282
# MSE of the network on the train reviews: 0.529631
# Accuracy of the network on the train reviews: 50 %
# average diff of the network on the train reviews: 0.568661
# MSE of the network on the test reviews: 1.292846
# Accuracy of the network on the test reviews: 33 %
# average diff of the network on the test reviews: 0.889893
# [53,  3500] loss: 886.411
# MSE of the network on the train reviews: 0.474944
# Accuracy of the network on the train reviews: 56 %
# average diff of the network on the train reviews: 0.502223
# MSE of the network on the test reviews: 1.275635
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.852321
# [54,  3500] loss: 881.539
# MSE of the network on the train reviews: 0.462908
# Accuracy of the network on the train reviews: 57 %
# average diff of the network on the train reviews: 0.494714
# MSE of the network on the test reviews: 1.253802
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.845929
# [55,  3500] loss: 876.947
# MSE of the network on the train reviews: 0.499716
# Accuracy of the network on the train reviews: 53 %
# average diff of the network on the train reviews: 0.536670
# MSE of the network on the test reviews: 1.238693
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.863107
# [56,  3500] loss: 881.515
# MSE of the network on the train reviews: 0.508795
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.526357
# MSE of the network on the test reviews: 1.282555
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.853571
# [57,  3500] loss: 880.782
# MSE of the network on the train reviews: 0.699093
# Accuracy of the network on the train reviews: 47 %
# average diff of the network on the train reviews: 0.637500
# MSE of the network on the test reviews: 1.557563
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.933250
# [58,  3500] loss: 875.432
# MSE of the network on the train reviews: 0.486275
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.524393
# MSE of the network on the test reviews: 1.236810
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.859893
# [59,  3500] loss: 875.116
# MSE of the network on the train reviews: 0.505566
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.525420
# MSE of the network on the test reviews: 1.333212
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.869679
# [60,  3500] loss: 880.821
# MSE of the network on the train reviews: 0.482542
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.522527
# MSE of the network on the test reviews: 1.233704
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.858607
# [61,  3500] loss: 876.886
# MSE of the network on the train reviews: 0.493073
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.518000
# MSE of the network on the test reviews: 1.299510
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.860964
# [62,  3500] loss: 877.767
# MSE of the network on the train reviews: 0.481807
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.518259
# MSE of the network on the test reviews: 1.229012
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.852643
# [63,  3500] loss: 871.895
# MSE of the network on the train reviews: 0.555648
# Accuracy of the network on the train reviews: 48 %
# average diff of the network on the train reviews: 0.589634
# MSE of the network on the test reviews: 1.280065
# Accuracy of the network on the test reviews: 33 %
# average diff of the network on the test reviews: 0.890714
# [64,  3500] loss: 878.242
# MSE of the network on the train reviews: 0.482968
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.522062
# MSE of the network on the test reviews: 1.283803
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.871071
# [65,  3500] loss: 870.339
# MSE of the network on the train reviews: 0.483293
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.524509
# MSE of the network on the test reviews: 1.239619
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.857214
# [66,  3500] loss: 865.852
# MSE of the network on the train reviews: 0.472408
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.513375
# MSE of the network on the test reviews: 1.222838
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.850250
# [67,  3500] loss: 868.654
# MSE of the network on the train reviews: 0.470494
# Accuracy of the network on the train reviews: 56 %
# average diff of the network on the train reviews: 0.503071
# MSE of the network on the test reviews: 1.261189
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.851321
# [68,  3500] loss: 867.367
# MSE of the network on the train reviews: 0.569239
# Accuracy of the network on the train reviews: 46 %
# average diff of the network on the train reviews: 0.605402
# MSE of the network on the test reviews: 1.294878
# Accuracy of the network on the test reviews: 32 %
# average diff of the network on the test reviews: 0.900286
# [69,  3500] loss: 869.823
# MSE of the network on the train reviews: 0.474013
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.511732
# MSE of the network on the test reviews: 1.226805
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.847036
# [70,  3500] loss: 864.846
# MSE of the network on the train reviews: 0.645880
# Accuracy of the network on the train reviews: 49 %
# average diff of the network on the train reviews: 0.603723
# MSE of the network on the test reviews: 1.529904
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.919786
# [71,  3500] loss: 857.573
# MSE of the network on the train reviews: 0.502334
# Accuracy of the network on the train reviews: 52 %
# average diff of the network on the train reviews: 0.539143
# MSE of the network on the test reviews: 1.250369
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.867107
# [72,  3500] loss: 864.102
# MSE of the network on the train reviews: 0.517786
# Accuracy of the network on the train reviews: 51 %
# average diff of the network on the train reviews: 0.555063
# MSE of the network on the test reviews: 1.268097
# Accuracy of the network on the test reviews: 34 %
# average diff of the network on the test reviews: 0.880643
# [73,  3500] loss: 864.527
# MSE of the network on the train reviews: 0.467106
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.507259
# MSE of the network on the test reviews: 1.281951
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.866286
# [74,  3500] loss: 867.035
# MSE of the network on the train reviews: 0.510232
# Accuracy of the network on the train reviews: 51 %
# average diff of the network on the train reviews: 0.552973
# MSE of the network on the test reviews: 1.282912
# Accuracy of the network on the test reviews: 33 %
# average diff of the network on the test reviews: 0.883500
# [75,  3500] loss: 865.763
# MSE of the network on the train reviews: 0.466247
# Accuracy of the network on the train reviews: 56 %
# average diff of the network on the train reviews: 0.504848
# MSE of the network on the test reviews: 1.264280
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.858500
# [76,  3500] loss: 854.947
# MSE of the network on the train reviews: 0.471758
# Accuracy of the network on the train reviews: 56 %
# average diff of the network on the train reviews: 0.506018
# MSE of the network on the test reviews: 1.258146
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.852893
# [77,  3500] loss: 862.742
# MSE of the network on the train reviews: 0.486671
# Accuracy of the network on the train reviews: 56 %
# average diff of the network on the train reviews: 0.508420
# MSE of the network on the test reviews: 1.345381
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.874429
# [78,  3500] loss: 863.118
# MSE of the network on the train reviews: 0.528138
# Accuracy of the network on the train reviews: 51 %
# average diff of the network on the train reviews: 0.560187
# MSE of the network on the test reviews: 1.275140
# Accuracy of the network on the test reviews: 34 %
# average diff of the network on the test reviews: 0.875107
# [79,  3500] loss: 865.725
# MSE of the network on the train reviews: 0.491677
# Accuracy of the network on the train reviews: 52 %
# average diff of the network on the train reviews: 0.536679
# MSE of the network on the test reviews: 1.239960
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.860679
# [80,  3500] loss: 856.680
# MSE of the network on the train reviews: 0.455821
# Accuracy of the network on the train reviews: 57 %
# average diff of the network on the train reviews: 0.495830
# MSE of the network on the test reviews: 1.270447
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.859643
# [81,  3500] loss: 864.420
# MSE of the network on the train reviews: 0.481725
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.519884
# MSE of the network on the test reviews: 1.239646
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.858071
# [82,  3500] loss: 859.053
# MSE of the network on the train reviews: 0.473881
# Accuracy of the network on the train reviews: 55 %
# average diff of the network on the train reviews: 0.510848
# MSE of the network on the test reviews: 1.253155
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.853893
# [83,  3500] loss: 854.537
# MSE of the network on the train reviews: 0.531931
# Accuracy of the network on the train reviews: 49 %
# average diff of the network on the train reviews: 0.575393
# MSE of the network on the test reviews: 1.277734
# Accuracy of the network on the test reviews: 33 %
# average diff of the network on the test reviews: 0.890429
# [84,  3500] loss: 855.435
# MSE of the network on the train reviews: 0.461189
# Accuracy of the network on the train reviews: 56 %
# average diff of the network on the train reviews: 0.497464
# MSE of the network on the test reviews: 1.242287
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.851393
# [85,  3500] loss: 847.306
# MSE of the network on the train reviews: 0.578044
# Accuracy of the network on the train reviews: 52 %
# average diff of the network on the train reviews: 0.567027
# MSE of the network on the test reviews: 1.460487
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.904786
# [86,  3500] loss: 862.420
# MSE of the network on the train reviews: 0.449374
# Accuracy of the network on the train reviews: 56 %
# average diff of the network on the train reviews: 0.482929
# MSE of the network on the test reviews: 1.284584
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.859357
# [87,  3500] loss: 809.118
# MSE of the network on the train reviews: 0.521489
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.514571
# MSE of the network on the test reviews: 1.425959
# Accuracy of the network on the test reviews: 36 %
# average diff of the network on the test reviews: 0.884857
# [88,  3500] loss: 790.931
# MSE of the network on the train reviews: 0.440772
# Accuracy of the network on the train reviews: 58 %
# average diff of the network on the train reviews: 0.458562
# MSE of the network on the test reviews: 1.263461
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.837036
# [89,  3500] loss: 789.159
# MSE of the network on the train reviews: 0.433757
# Accuracy of the network on the train reviews: 58 %
# average diff of the network on the train reviews: 0.460580
# MSE of the network on the test reviews: 1.228156
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.831214
# [90,  3500] loss: 786.357
# MSE of the network on the train reviews: 0.432069
# Accuracy of the network on the train reviews: 58 %
# average diff of the network on the train reviews: 0.459429
# MSE of the network on the test reviews: 1.248525
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.842500
# [91,  3500] loss: 779.373
# MSE of the network on the train reviews: 0.447377
# Accuracy of the network on the train reviews: 58 %
# average diff of the network on the train reviews: 0.454839
# MSE of the network on the test reviews: 1.335727
# Accuracy of the network on the test reviews: 37 %
# average diff of the network on the test reviews: 0.850929
# [92,  3500] loss: 747.555
# MSE of the network on the train reviews: 0.427257
# Accuracy of the network on the train reviews: 60 %
# average diff of the network on the train reviews: 0.437929
# MSE of the network on the test reviews: 1.295657
# Accuracy of the network on the test reviews: 38 %
# average diff of the network on the test reviews: 0.836357
# [93,  3500] loss: 733.339
# MSE of the network on the train reviews: 0.387416
# Accuracy of the network on the train reviews: 62 %
# average diff of the network on the train reviews: 0.403687
# MSE of the network on the test reviews: 1.224438
# Accuracy of the network on the test reviews: 39 %
# average diff of the network on the test reviews: 0.813929
# [94,  3500] loss: 739.633
# MSE of the network on the train reviews: 0.455022
# Accuracy of the network on the train reviews: 54 %
# average diff of the network on the train reviews: 0.489071
# MSE of the network on the test reviews: 1.228043
# Accuracy of the network on the test reviews: 35 %
# average diff of the network on the test reviews: 0.850357
# [95,  3500] loss: 727.102
# MSE of the network on the train reviews: 0.387043
# Accuracy of the network on the train reviews: 61 %
# average diff of the network on the train reviews: 0.412786
# MSE of the network on the test reviews: 1.226039
# Accuracy of the network on the test reviews: 38 %
# average diff of the network on the test reviews: 0.815143
# [96,  3500] loss: 704.981
# MSE of the network on the train reviews: 0.388353
# Accuracy of the network on the train reviews: 61 %
# average diff of the network on the train reviews: 0.407991
# MSE of the network on the test reviews: 1.193848
# Accuracy of the network on the test reviews: 39 %
# average diff of the network on the test reviews: 0.798036
# [97,  3500] loss: 699.471
# MSE of the network on the train reviews: 0.380272
# Accuracy of the network on the train reviews: 62 %
# average diff of the network on the train reviews: 0.396848
# MSE of the network on the test reviews: 1.187268
# Accuracy of the network on the test reviews: 39 %
# average diff of the network on the test reviews: 0.798929
# [98,  3500] loss: 694.428
# MSE of the network on the train reviews: 0.387462
# Accuracy of the network on the train reviews: 62 %
# average diff of the network on the train reviews: 0.400143
# MSE of the network on the test reviews: 1.205769
# Accuracy of the network on the test reviews: 40 %
# average diff of the network on the test reviews: 0.791571
# [99,  3500] loss: 692.270
# MSE of the network on the train reviews: 0.379949
# Accuracy of the network on the train reviews: 63 %
# average diff of the network on the train reviews: 0.391813
# MSE of the network on the test reviews: 1.208578
# Accuracy of the network on the test reviews: 39 %
# average diff of the network on the test reviews: 0.797143
# [100,  3500] loss: 694.435
# MSE of the network on the train reviews: 0.375853
# Accuracy of the network on the train reviews: 63 %
# average diff of the network on the train reviews: 0.392330
# MSE of the network on the test reviews: 1.257402
# Accuracy of the network on the test reviews: 38 %
# average diff of the network on the test reviews: 0.821821
# Finished Training

# %%
reviews = ["this movie was so bad","the movie was okay at best","the movie was trash","this is the greatest thing I have ever seen!"]
with torch.no_grad():
    for review in reviews:
        review_data = torch.Tensor(embedder.str_to_image(review).reshape([-1,1,PADDED_LEN,EMBEDDING_DIM])).to(device)
        res = model(review_data)
        print("review: " + review + ". rank: " + str(res.item()))
# Out:
# review: this movie was so bad. rank: 0.7956054210662842
# review: the movie was okay at best. rank: 3.5871520042419434
# review: the movie was trash. rank: 1.498773455619812
# review: this is the greatest thing I have ever seen!. rank: 4.1483869552612305
